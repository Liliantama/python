# %% [markdown]
# base_url='https://api.nasa.gov/DONKI/CME'

# %%
! pip install requests

# %%
base_url='https://api.nasa.gov/DONKI/CME?'

# %%
start_date=2016-9-1

# %%
end_date=2016-9-30

# %%
api_code='lhMmghy3DDLVUMj1E7LL8U90LsWO7N5TY0XycEe7'

# %%
import requests

# %%
cme_base_url ='https://api.nasa.gov/DONKI/CME?'
cme_url = f'{cme_base_url}startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key={api_code}'

# %%
requests.get(cme_url)
# Out:
# <Response [200]>

# %%
response = requests.get(cme_url)

# %%
response.json()
# Out:
# [{'activityID': '2016-09-02T06:18:00-CME-001',
#   'catalog': 'M2M_CATALOG',
#   'startTime': '2016-09-02T06:18Z',
#   'sourceLocation': '',
#   'activeRegionNum': None,
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/11209/-1',
#   'note': 'Start time is time when seen in SOHO LASCO C3 due to a data gap in SOHO LASCO C2 imagery.',
#   'submissionTime': '2016-09-02T14:42Z',
#   'instruments': [{'displayName': 'SOHO: LASCO/C3'},
#    {'displayName': 'SOHO: LASCO/C2'},
#    {'displayName': 'STEREO A: SECCHI/COR2'}],
#   'cmeAnalyses': [{'isMostAccurate': True,
#     'time21_5': '2016-09-02T19:15Z',
#     'latitude': 35.0,
#     'longitude': -87.0,
#     'halfAngle': 27.0,
#     'speed': 218.0,
#     'type': 'S',
#     'featureCode': 'null',
#     'imageType': None,
#     'measurementTechnique': 'null',
#     'note': '',
#     'levelOfData': 0,
#     'tilt': None,
#     'minorHalfWidth': None,
#     'speedMeasuredAtHeight': None,
# ...

# %% [markdown]
# ##GEOMAGNETIC STORM

# %%
api_code='lhMmghy3DDLVUMj1E7LL8U90LsWO7N5TY0XycEe7'

# %%
base_url='https://api.nasa.gov/DONKI/GST?'
url = f'{base_url}startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key={api_code}'

# %%
import requests

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
response=requests.get(url)

# %%
response.json()
# Out:
# [{'gstID': '2016-09-01T21:00:00-GST-001',
#   'startTime': '2016-09-01T21:00Z',
#   'allKpIndex': [{'observedTime': '2016-09-02T00:00Z',
#     'kpIndex': 6.0,
#     'source': 'NOAA'},
#    {'observedTime': '2016-09-02T06:00Z', 'kpIndex': 6.0, 'source': 'NOAA'},
#    {'observedTime': '2016-09-03T06:00Z', 'kpIndex': 6.0, 'source': 'NOAA'}],
#   'linkedEvents': [{'activityID': '2016-09-01T10:00:00-HSS-001'}],
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11205/-1',
#   'submissionTime': '2016-09-02T12:18Z'},
#  {'gstID': '2016-09-27T15:00:00-GST-001',
#   'startTime': '2016-09-27T15:00Z',
#   'allKpIndex': [{'observedTime': '2016-09-27T18:00Z',
#     'kpIndex': 6.0,
#     'source': 'NOAA'}],
#   'linkedEvents': [{'activityID': '2016-09-26T07:05:00-HSS-001'}],
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/11309/-1',
#   'submissionTime': '2016-09-27T18:24Z'},
#  {'gstID': '2016-09-28T18:00:00-GST-001',
#   'startTime': '2016-09-28T18:00Z',
# ...

# %% [markdown]
# ##INTERPLANETARY SHOCK

# %%
api_code='lhMmghy3DDLVUMj1E7LL8U90LsWO7N5TY0XycEe7'

# %%
base_url='https://api.nasa.gov/DONKI/IPS?'
url = f'{base_url}startDate=2016-09-01&endDate=2016-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL&api_key={api_code}'

# %%
import requests

# %%
response=requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'catalog': 'M2M_CATALOG',
#   'activityID': '2016-09-17T14:00:00-IPS-001',
#   'location': 'STEREO A',
#   'eventTime': '2016-09-17T14:00Z',
#   'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/IPS/11277/-1',
#   'instruments': [{'displayName': 'STEREO A: IMPACT'}],
#   'submissionTime': '2016-09-19T14:20Z'}]
